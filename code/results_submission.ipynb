# %% [markdown]
# ## Context
# This notebook contains the code for reproducing our results. It calls the `main.py` file with the right configuration files (from the `..\configs` folder) to generate the results.
#
# If you want to see the implementation of the different algorithms, then the `agents.py` file is what you want to look for. For the plotting, refer to `analyse.py`, who's functions are called by `main.py`.
#
# This notebook can be run on google colab or locally. It is reccomended to be run on google colab as it takes less than half of the running time.
#
# To be run in colab, you first need to :
# * upload and open this notebook to your google colab (the next steps are to be done from colab)
# * uncomment and run the contents of the next cell
# * put the `COLAB` variable to `True`

# %%
# This clones the repo so that you can call the code.
#!git config --global user.email "tobia.fjellman@epfl.ch"
#!git config --global user.name "Tiddy-Fje"
#!git clone https://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@github.com/Tiddy-Fje/rl-project-Rayan-Tara.git

# To make sure you have the most recent version you can pull with the following command
#!cd rl-project-Rayan-Tara/ && git pull origin

# Installs the only missing package to run the code
#!pip install gymnasium

#!ls

# %%
COLAB = False
COLAB_PATH = ''

if COLAB :
  import sys
  COLAB_PATH = 'rl-project-Rayan-Tara/code/'
  sys.path.append(COLAB_PATH)

import main
import analyse

# %% [markdown]
# ## Random agent

# %%
main.main( f'{COLAB_PATH}../configs/random.yml', COLAB )
# Out:
# Starting to train ...
# 0.0 % of episodes done
# 10.0 % of episodes done
# 20.0 % of episodes done
# 30.0 % of episodes done
# 40.0 % of episodes done
# 50.0 % of episodes done
# 60.0 % of episodes done
# 70.0 % of episodes done
# 80.0 % of episodes done
# 90.0 % of episodes done
# Training took: 0.153 min
# Starting to plot ...
# Done plotting !

# %% [markdown]
# ## DQN agent

# %%
main.main( f'{COLAB_PATH}../configs/vanilla.yml', COLAB )
# Out:
# Starting to train ...
# 0.0 % of episodes done
# 10.0 % of episodes done
# 20.0 % of episodes done
# 30.0 % of episodes done
# 40.0 % of episodes done
# 50.0 % of episodes done
# 60.0 % of episodes done
# 70.0 % of episodes done
# 80.0 % of episodes done
# 90.0 % of episodes done
# Training took: 4.05 min
# Starting to plot ...
# foo
# Done plotting !

# %%
main.main( f'{COLAB_PATH}../configs/heuristic_right.yml', COLAB )

# %%
main.main( f'{COLAB_PATH}../configs/heuristic_too_low.yml', COLAB )

# %%
main.main( f'{COLAB_PATH}../configs/heuristic_too_high.yml', COLAB )

# %% [markdown]
# ## Dyna agent

# %%
main.main( f'{COLAB_PATH}../configs/dyna_right.yml', COLAB )

# %%
main.main( f'{COLAB_PATH}../configs/dyna_too_fine.yml', COLAB )

# %%
main.main( f'{COLAB_PATH}../configs/dyna_too_corse.yml', COLAB )

# %%
main.main( f'{COLAB_PATH}../configs/dyna_long.yml', COLAB )
